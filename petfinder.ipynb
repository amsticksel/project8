# %%
# Dependencies
import requests
import json
import pandas as pd
import csv
import os

# %%
# url = "https://api.petfinder.com/v2/oauth2/token"
# client_id = "lQI1GugWEHDOyN5YRIR8C8gkvTgOO3bJfjkJcC0VxNvSRvUCJj"
# client_secret = "hux5D899a8oQoMdUWxq7iw4iw9kl3p8bS89b8o6b"
# body = {"grant_type": "client_credentials",
#        "client_id": client_id,
#        "client_secret": client_secret}
# headers = {}
# r = requests.post(url, data=json.dumps(body), headers=headers)
# result_json = r.json()
# token = result_json["access_token"]

# params = {
#     "type": "dog",
#     "page": "1",
# }
# headers = {
#     "Authorization": f"Bearer {token}"
# }
dogs=[]
# for i in range(0, 1000):
#     params["page"] = str(int(params["page"]) + 1)
#     result = requests.get("https://api.petfinder.com/v2/animals", params=params, headers=headers)
#     dogs.extend(result.json()["animals"])
# print(dogs)
# from collections import Counter
# cnt = Counter()
# for dog in dogs:
#    breed = dog['breeds']['primary']
#    cnt[breed] += 1
# print(cnt)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
dogs[0].keys()
# Out:
# dict_keys(['id', 'organization_id', 'url', 'type', 'species', 'breeds', 'colors', 'age', 'gender', 'size', 'coat', 'attributes', 'environment', 'tags', 'name', 'description', 'photos', 'status', 'status_changed_at', 'published_at', 'distance', 'contact', '_links'])

# %%
dog_data = []
for dog in dogs:
    dog_data.append(dog.values())

# %%
df = pd.DataFrame(dog_data)

# %%
df.columns = ['id', 'organization_id', 'url', 'type', 'species', 'breeds', 'colors', 'age', 'gender', 'size', 'coat', 'attributes', 'environment', 'tags', 'name', 'description', 'photos', 'status', 'status_changed_at', 'published_at', 'distance', 'contact', '_links']

# %%
df['name'] = df.name.str.lower()

# %%
df.name.value_counts()
df
# Out:
#              id organization_id  \
# 0      47072487           CA803
# 1      47072473           IN112
# 2      47072474           NC924
# 3      47072469           GA916
# 4      47072434           ON305
# ...         ...             ...
# 19995  47018540           TX514
# 19996  47018528           TX514
# 19997  47018497            IN24
# 19998  47018505           MA243
# 19999  47018460          NC1032
#
#                                                      url type species  \
# 0      https://www.petfinder.com/dog/rowan-47072487/c...  Dog     Dog
# 1      https://www.petfinder.com/dog/freeway-47072473...  Dog     Dog
# 2      https://www.petfinder.com/dog/tokie-47072474/n...  Dog     Dog
# 3      https://www.petfinder.com/dog/rambo-47072469/f...  Dog     Dog
# 4      https://www.petfinder.com/dog/rosie-and-posie-...  Dog     Dog
# ...                                                  ...  ...     ...
# 19995  https://www.petfinder.com/dog/enzo-47018540/tx...  Dog     Dog
# 19996  https://www.petfinder.com/dog/teddy-47018528/t...  Dog     Dog
# 19997  https://www.petfinder.com/dog/otto-47018497/in...  Dog     Dog
# 19998  https://www.petfinder.com/dog/blanca-47018505/...  Dog     Dog
# 19999  https://www.petfinder.com/dog/alexis-47018460/...  Dog     Dog
#
#                                                   breeds  \
# 0      {'primary': 'Siberian Husky', 'secondary': Non...
# 1      {'primary': 'Jack Russell Terrier', 'secondary...
# 2      {'primary': 'Shih Tzu', 'secondary': None, 'mi...
# 3      {'primary': 'Cocker Spaniel', 'secondary': Non...
# 4      {'primary': 'Goldendoodle', 'secondary': None,...
# ...                                                  ...
# 19995  {'primary': 'Australian Shepherd', 'secondary'...
# 19996  {'primary': 'Labrador Retriever', 'secondary':...
# 19997  {'primary': 'Staffordshire Bull Terrier', 'sec...
# 19998  {'primary': 'West Highland White Terrier / Wes...
# 19999  {'primary': 'Pit Bull Terrier', 'secondary': N...
#
#                                                   colors     age  gender  \
# 0      {'primary': None, 'secondary': None, 'tertiary...   Adult  Female
# 1      {'primary': 'Brown / Chocolate', 'secondary': ...  Senior    Male
# 2      {'primary': 'White / Cream', 'secondary': None...   Young    Male
# 3      {'primary': 'Black', 'secondary': 'Yellow / Ta...   Young    Male
# 4      {'primary': None, 'secondary': None, 'tertiary...    Baby  Female
# ...                                                  ...     ...     ...
# 19995  {'primary': None, 'secondary': None, 'tertiary...   Adult    Male
# 19996  {'primary': None, 'secondary': None, 'tertiary...   Young    Male
# 19997  {'primary': None, 'secondary': None, 'tertiary...   Adult    Male
# 19998  {'primary': None, 'secondary': None, 'tertiary...   Adult  Female
# 19999  {'primary': None, 'secondary': None, 'tertiary...   Adult  Female
#
#          size  ... tags             name  \
# 0      Medium  ...   []            rowan
# 1       Small  ...   []          freeway
# 2       Small  ...   []            tokie
# 3      Medium  ...   []            rambo
# 4      Medium  ...   []  rosie and posie
# ...       ...  ...  ...              ...
# 19995  Medium  ...   []             enzo
# 19996  Medium  ...   []            teddy
# 19997  Medium  ...   []             otto
# 19998   Small  ...   []           blanca
# 19999  Medium  ...   []           alexis
#
#                                              description  \
# 0      How I arrived: I was brought in by my previous...
# 1      Meet Freeway ! He is a total lovebug and wants...
# 2      This little guy is just about a year old he ca...
# 3      WAGS RESCUE WELCOMES RAMBO... This absolutely ...
# 4      Rosie and Posie are 11 week old girls each loo...
# ...                                                  ...
# 19995                                               None
# 19996                                               None
# 19997  Hey there, I&amp;#39;m Otto! I am a silly guy ...
# 19998  Meet Blanca, our 8 year-old West Highland Terr...
# 19999                                               None
#
#                                                   photos     status  \
# 0                                                     []  adoptable
# 1      [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 2      [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 3      [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 4      [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# ...                                                  ...        ...
# 19995  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 19996  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 19997  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 19998  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 19999  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
#
#               status_changed_at              published_at distance  \
# 0      2020-01-10T00:38:49+0000  2020-01-10T00:38:49+0000     None
# 1      2020-01-10T00:38:16+0000  2020-01-10T00:38:16+0000     None
# 2      2020-01-10T00:38:10+0000  2020-01-10T00:38:10+0000     None
# 3      2020-01-10T00:34:08+0000  2020-01-10T00:34:08+0000     None
# 4      2020-01-10T00:33:57+0000  2020-01-10T00:33:57+0000     None
# ...                         ...                       ...      ...
# 19995  2020-01-03T19:55:03+0000  2020-01-03T19:55:03+0000     None
# 19996  2020-01-03T19:55:02+0000  2020-01-03T19:55:02+0000     None
# 19997  2020-01-03T19:55:00+0000  2020-01-03T19:55:00+0000     None
# 19998  2020-01-03T19:55:00+0000  2020-01-03T19:55:00+0000     None
# 19999  2020-01-03T19:54:53+0000  2020-01-03T19:54:53+0000     None
#
#                                                  contact  \
# 0      {'email': 'info@sdhumane.org', 'phone': '(619)...
# 1      {'email': 'manager@marionhumane.com', 'phone':...
# 2      {'email': 'handerson11@yahoo.com', 'phone': '3...
# 3      {'email': 'wandgrescue@gmail.com', 'phone': No...
# 4      {'email': 'bluecollaredcanines@hotmail.com', '...
# ...                                                  ...
# 19995  {'email': 'animal.customerservice@austintexas....
# 19996  {'email': 'animal.customerservice@austintexas....
# 19997  {'email': 'adoptionhelp@cityoffortwayne.org', ...
# 19998  {'email': 'Moreilly@mspca.org', 'phone': '(508...
# 19999  {'email': 'llee@guilfordcountync.gov', 'phone'...
#
#                                                   _links
# 0      {'self': {'href': '/v2/animals/47072487'}, 'ty...
# 1      {'self': {'href': '/v2/animals/47072473'}, 'ty...
# 2      {'self': {'href': '/v2/animals/47072474'}, 'ty...
# 3      {'self': {'href': '/v2/animals/47072469'}, 'ty...
# 4      {'self': {'href': '/v2/animals/47072434'}, 'ty...
# ...                                                  ...
# 19995  {'self': {'href': '/v2/animals/47018540'}, 'ty...
# 19996  {'self': {'href': '/v2/animals/47018528'}, 'ty...
# 19997  {'self': {'href': '/v2/animals/47018497'}, 'ty...
# 19998  {'self': {'href': '/v2/animals/47018505'}, 'ty...
# 19999  {'self': {'href': '/v2/animals/47018460'}, 'ty...
#
# [20000 rows x 23 columns]

# %%
dogs[0].keys()
# Out:
# dict_keys(['id', 'organization_id', 'url', 'type', 'species', 'breeds', 'colors', 'age', 'gender', 'size', 'coat', 'attributes', 'environment', 'tags', 'name', 'description', 'photos', 'status', 'status_changed_at', 'published_at', 'distance', 'contact', '_links'])

# %%
# Pretty print JSON for all launchpads
response = requests.get(url).json()
#params={'q': 'requests+language:python'},
#    headers={'Accept': 'application/vnd.github.v3.text-match+json'},
#"grant_type=client_credentials&client_id={CLIENT-ID}&client_secret={CLIENT-SECRET}"

#"Authorization: Bearer {YOUR_ACCESS_TOKEN}" GET https://api.petfinder.com/v2/{CATEGORY}/{ACTION}?{parameter_1}={value_1}&{parameter_2}={value_2}

# %%
# Pretty print JSON for a specific launchpad
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "detail": "Access token invalid or expired",
#     "status": 401,
#     "title": "Unauthorized",
#     "type": "https://httpstatus.es/401"
# }

# %%
primary_breeds =[]
secondary_breeds = []
dogcity =[]
dogstate = []
dogzip = []
dogcountry = []
dogphoto = []
dogcolor1 = []
dogcolor2 = []
dogcolor3 = []
spayed_neutered = []
house_trained = []
special_needs = []
shots_current = []
envchildren = []
envdogs = []
envcats = []

for k,v in df.iterrows():
    primary_breeds.append(v.breeds['primary'])
    secondary_breeds.append(v.breeds['secondary'])
    dogcity.append(v.contact['address']['city'])
    dogstate.append(v.contact['address']['state'])
    dogzip.append(v.contact['address']['postcode'])
    dogcountry.append(v.contact['address']['country'])
    dogcolor1.append(v.colors['primary'])
    dogcolor2.append(v.colors['secondary'])
    dogcolor3.append(v.colors['tertiary'])
    spayed_neutered.append(v.attributes['spayed_neutered'])
    house_trained.append(v.attributes['house_trained'])
    special_needs.append(v.attributes['special_needs'])
    shots_current.append(v.attributes['shots_current'])
    envchildren.append(v.environment['children'])
    envdogs.append(v.environment['dogs'])
    envcats.append(v.environment['cats'])

# %%
df['primary_breed']= primary_breeds

# %%
df['secondary_breeds'] = secondary_breeds

# %%
df['city'] = dogcity
df['state'] = dogstate
df['zip'] = dogzip
df['country'] = dogcountry
df['color1'] = dogcolor1
df['color2'] = dogcolor2
df['color3'] = dogcolor3
df['spayed_neutered'] = spayed_neutered
df['house_trained'] = house_trained
df['special_needs'] = special_needs
df['shots_current'] = shots_current
df['friendly_children'] = envchildren
df['friendly_dogs'] = envdogs
df['friendly_cats'] = envcats

# %%
df['published_at'] = pd.to_datetime(df.published_at)
df['published_at'] = df['published_at'].dt.tz_convert('US/Central')


df['status_changed_at'] = pd.to_datetime(df.status_changed_at)
df['status_changed_at'] = df['status_changed_at'].dt.tz_convert('US/Central')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 39 columns):
# id                   20000 non-null int64
# organization_id      20000 non-null object
# url                  20000 non-null object
# type                 20000 non-null object
# species              20000 non-null object
# breeds               20000 non-null object
# colors               20000 non-null object
# age                  20000 non-null object
# gender               20000 non-null object
# size                 20000 non-null object
# coat                 6638 non-null object
# attributes           20000 non-null object
# environment          20000 non-null object
# tags                 20000 non-null object
# name                 20000 non-null object
# description          14516 non-null object
# photos               20000 non-null object
# status               20000 non-null object
# status_changed_at    20000 non-null datetime64[ns, US/Central]
# published_at         20000 non-null datetime64[ns, US/Central]
# distance             0 non-null object
# contact              20000 non-null object
# _links               20000 non-null object
# primary_breed        20000 non-null object
# secondary_breeds     7982 non-null object
# city                 20000 non-null object
# state                20000 non-null object
# zip                  19961 non-null object
# country              20000 non-null object
# color1               6624 non-null object
# color2               2999 non-null object
# color3               352 non-null object
# spayed_neutered      20000 non-null bool
# house_trained        20000 non-null bool
# special_needs        20000 non-null bool
# shots_current        20000 non-null bool
# friendly_children    6561 non-null object
# friendly_dogs        8198 non-null object
# friendly_cats        4102 non-null object
# dtypes: bool(4), datetime64[ns, US/Central](2), int64(1), object(32)
# memory usage: 5.4+ MB

# %%
df['published_at'] = df['published_at'].dt.tz_convert('US/Central')

# %%
df['status'].value_counts()
# Out:
# adoptable    18214
# adopted       1746
# found           40
# Name: status, dtype: int64

# %%
df.to_csv('dogs.csv')
dogsdf = pd.read_csv('dogs.csv')

# %%
dogsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 40 columns):
# Unnamed: 0           20000 non-null int64
# id                   20000 non-null int64
# organization_id      20000 non-null object
# url                  20000 non-null object
# type                 20000 non-null object
# species              20000 non-null object
# breeds               20000 non-null object
# colors               20000 non-null object
# age                  20000 non-null object
# gender               20000 non-null object
# size                 20000 non-null object
# coat                 6638 non-null object
# attributes           20000 non-null object
# environment          20000 non-null object
# tags                 20000 non-null object
# name                 20000 non-null object
# description          14516 non-null object
# photos               20000 non-null object
# status               20000 non-null object
# status_changed_at    20000 non-null object
# published_at         20000 non-null object
# distance             0 non-null float64
# contact              20000 non-null object
# _links               20000 non-null object
# primary_breed        20000 non-null object
# secondary_breeds     7982 non-null object
# city                 20000 non-null object
# state                20000 non-null object
# zip                  19961 non-null object
# country              20000 non-null object
# color1               6624 non-null object
# color2               2999 non-null object
# color3               352 non-null object
# spayed_neutered      20000 non-null bool
# house_trained        20000 non-null bool
# special_needs        20000 non-null bool
# shots_current        20000 non-null bool
# friendly_children    6561 non-null object
# friendly_dogs        8198 non-null object
# friendly_cats        4102 non-null object
# dtypes: bool(4), float64(1), int64(2), object(33)
# memory usage: 5.6+ MB

# %%
from datetime import timedelta
from datetime import datetime as dt

# %%
df['published_at'].
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-c01b10be8e52> in <module>
# ----> 1 df['published_at'].tz_convert('US/Central')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in tz_convert(self, tz, axis, level, copy)
#    9701             if level not in (None, 0, ax.name):
#    9702                 raise ValueError("The level {0} is not valid".format(level))
# -> 9703             ax = _tz_convert(ax, tz)
#    9704
#    9705         result = self._constructor(self._data, copy=copy)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _tz_convert(ax, tz)
#    9684                     ax_name = self._get_axis_name(axis)
#    9685                     raise TypeError(
# -> 9686                         "%s is not a valid DatetimeIndex or " "PeriodIndex" % ax_name
#    9687                     )
#    9688                 else:
#
# TypeError: index is not a valid DatetimeIndex or PeriodIndex

# %%
#df.to_csv(r'doggies.csv')

# %%
#data = pd.read_csv("doggies.csv")
#data.head()
# Out:
#    Unnamed: 0        id organization_id  \
# 0           0  47054086            KY51
# 1           1  47054009           BC254
# 2           2  47054128           MN423
# 3           3  47054071           TN627
# 4           4  47054122          TX1950
#
#                                                  url type species  \
# 0  https://www.petfinder.com/dog/rosco-47054086/k...  Dog     Dog
# 1  https://www.petfinder.com/dog/poneh-47054009/b...  Dog     Dog
# 2  https://www.petfinder.com/dog/marlie-47054128/...  Dog     Dog
# 3  https://www.petfinder.com/dog/cupid-courtesy-p...  Dog     Dog
# 4  https://www.petfinder.com/dog/max-47054122/tx/...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Rottweiler', 'secondary': None, '...
# 1  {'primary': 'English Shepherd', 'secondary': N...
# 2  {'primary': 'Spaniel', 'secondary': 'Mixed Bre...
# 3  {'primary': 'Chihuahua', 'secondary': 'Miniatu...
# 4  {'primary': 'Plott Hound', 'secondary': 'Mixed...
#
#                                               colors     age  gender  ...  \
# 0  {'primary': 'Black', 'secondary': 'Brown / Cho...   Adult    Male  ...
# 1  {'primary': 'Red / Chestnut / Orange', 'second...   Young  Female  ...
# 2  {'primary': None, 'secondary': None, 'tertiary...    Baby  Female  ...
# 3  {'primary': 'Bicolor', 'secondary': None, 'ter...  Senior    Male  ...
# 4  {'primary': None, 'secondary': None, 'tertiary...   Adult    Male  ...
#
#                                          description  \
# 0  Please go to our website at www.logancohumane....
# 1  Poneh\nBreed: English Shepherd Mix\nAge: 1 yr\...
# 2                                                NaN
# 3  Meet Cupid! He is 11 years young! He is neuter...
# 4  Max is absolutely the sweetest dog. He is a st...
#
#                                               photos     status  \
# 0  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 1  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 2                                                 []  adoptable
# 3  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 4                                                 []  adoptable
#
#           status_changed_at               published_at distance  \
# 0  2020-01-08T03:07:41+0000  2020-01-08 03:07:41+00:00      NaN
# 1  2020-01-08T03:07:24+0000  2020-01-08 03:07:24+00:00      NaN
# 2  2020-01-08T03:06:19+0000  2020-01-08 03:06:19+00:00      NaN
# 3  2020-01-08T03:06:19+0000  2020-01-08 03:06:19+00:00      NaN
# 4  2020-01-08T03:06:18+0000  2020-01-08 03:06:18+00:00      NaN
#
#                                              contact  \
# 0  {'email': 'adoptlcpets@gmail.com', 'phone': '(...
# 1  {'email': 'dogs.laldr@gmail.com', 'phone': Non...
# 2  {'email': 'info@animalhumanesociety.org', 'pho...
# 3  {'email': 'cathysewell1123@outlook.com', 'phon...
# 4  {'email': 'adopt@houstonpetsalive.org', 'phone...
#
#                                               _links     primary_breed  \
# 0  {'self': {'href': '/v2/animals/47054086'}, 'ty...        Rottweiler
# 1  {'self': {'href': '/v2/animals/47054009'}, 'ty...  English Shepherd
# 2  {'self': {'href': '/v2/animals/47054128'}, 'ty...           Spaniel
# 3  {'self': {'href': '/v2/animals/47054071'}, 'ty...         Chihuahua
# 4  {'self': {'href': '/v2/animals/47054122'}, 'ty...       Plott Hound
#
#      secondary_breeds
# 0                 NaN
# 1                 NaN
# 2         Mixed Breed
# 3  Miniature Pinscher
# 4         Mixed Breed
#
# [5 rows x 26 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-19d7bad51a30> in <module>
#       1 from datetime import timedelta
#       2 from datetime import datetime as dt
# ----> 3 df['published_at'].dt.tz_localize('UTC').dt.tz_convert('US/Central')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     341             pass  # we raise an attribute error anyway
#     342
# --> 343         raise AttributeError("Can only use .dt accessor with datetimelike " "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values
